# %%
from google_play_scraper import app, Sort, reviews_all
import pandas as pd
import csv

result = app(
    'ovo.id',
    lang='id',
    country='id'
)

# %%
result
# Out:
# {'title': 'OVO',
#  'description': 'Dari jajan-jajan sampai makan besar, dari tagihan bulanan sampai belanja dadakan, dari online shopping sampai warung pinggir jalan – kapan pun dan di mana pun, semuanya bisa dibayar cukup #pakeOVOaja!\r\n\r\nYup bener, sekarang semuanya cukup pake OVO aja. Gak perlu repot sama uang cash, transaksi lebih mudah, cepat, dan aman pake OVO.\r\n\r\n\r\nMau tau OVO bisa ngapain aja?\r\n\r\n> Bisa Bayar Ini-Itu\r\nPakai OVO untuk transaksimu di 500.000+ merchant rekanan, beli pulsa, bayar tagihan bulanan, parkir, semua layanan Grab, dan semua pembelian di Tokopedia.\r\n\r\n> Hemat Transaksimu di Mana-Mana dengan OVO Points\r\n1 OVO Point = Rp1. Dapatkan OVO Points saat kamu bertransaksi di merchant rekanan, dan gunakan untuk menghemat transaksimu berikutnya.\r\n\r\n> Transfer ke Semua Bank\r\nUpgrade akun ke OVO Premier untuk rasakan praktisnya transfer ke sesama pengguna, atau ke semua Bank yang ada di Indonesia. Tanpa antre.\r\n\r\n> Top Up Mudah\r\nLewat Instan Top Up, ATM, internet/mobile banking, OVO Booth, abang Grab, atau debit langsung di dalam aplikasi OVO.\r\n\r\nDownload dan rasakan kemudahannya, sekarang!\r\n\r\nInstagram.com/ovo_id\r\nwww.ovo.id',
#  'descriptionHTML': 'Dari jajan-jajan sampai makan besar, dari tagihan bulanan sampai belanja dadakan, dari online shopping sampai warung pinggir jalan – kapan pun dan di mana pun, semuanya bisa dibayar cukup #pakeOVOaja!<br><br>Yup bener, sekarang semuanya cukup pake OVO aja. Gak perlu repot sama uang cash, transaksi lebih mudah, cepat, dan aman pake OVO.<br><br><br>Mau tau OVO bisa ngapain aja?<br><br>&gt; Bisa Bayar Ini-Itu<br>Pakai OVO untuk transaksimu di 500.000+ merchant rekanan, beli pulsa, bayar tagihan bulanan, parkir, semua layanan Grab, dan semua pembelian di Tokopedia.<br><br>&gt; Hemat Transaksimu di Mana-Mana dengan OVO Points<br>1 OVO Point = Rp1. Dapatkan OVO Points saat kamu bertransaksi di merchant rekanan, dan gunakan untuk menghemat transaksimu berikutnya.<br><br>&gt; Transfer ke Semua Bank<br>Upgrade akun ke OVO Premier untuk rasakan praktisnya transfer ke sesama pengguna, atau ke semua Bank yang ada di Indonesia. Tanpa antre.<br><br>&gt; Top Up Mudah<br>Lewat Instan Top Up, ATM, internet/mobile banking, OVO Booth, abang Grab, atau debit langsung di dalam aplikasi OVO.<br><br>Download dan rasakan kemudahannya, sekarang!<br><br>Instagram.com/ovo_id<br>www.ovo.id',
#  'summary': 'Indonesia’s one app to pay everywhere.',
#  'installs': '50.000.000+',
#  'minInstalls': 50000000,
#  'realInstalls': 68680906,
#  'score': 3.8564394,
#  'ratings': 1141062,
#  'reviews': 543557,
#  'histogram': [260899, 38205, 39371, 67907, 734674],
#  'price': 0,
#  'free': True,
#  'currency': 'IDR',
#  'sale': False,
#  'saleTime': None,
#  'originalPrice': None,
#  'saleText': None,
#  'offersIAP': False,
#  'inAppProductPrice': None,
#  'developer': 'PT Visionet Internasional',
#  'developerId': 'PT+Visionet+Internasional',
#  'developerEmail': 'cs@ovo.id',
#  'developerWebsite': 'https://www.ovo.id/',
#  'developerAddress': None,
#  'privacyPolicy': 'https://www.ovo.id/kebijakan-privasi',
#  'genre': 'Keuangan',
#  'genreId': 'FINANCE',
#  'categories': [{'name': 'Keuangan', 'id': 'FINANCE'}],
#  'icon': 'https://play-lh.googleusercontent.com/-kwEfsDenlwTCoWTe2BCAOv9YFPE4m5EReErdU_BsYYcISAtQ16JflXuwU8Okuw3Y6E',
#  'headerImage': 'https://play-lh.googleusercontent.com/nxk1EkXHSTVT0igPK7JIeP7IZr34HUhi2Jyeh1ZO9e5ToYy84h6Mqo224hqH7kjcvCM',
#  'screenshots': ['https://play-lh.googleusercontent.com/1duQgiqedNdvWwQw21LJ5wcMw0k_LS2THNyGxfMQu0Vbkx02WF6FNzMRCOo-hDutaz8',
#   'https://play-lh.googleusercontent.com/mexY5gJNJh0AXKDK05fMsH4NdlgQExzwFkfH9TOzuMI6jLILMIWFiOfxvS8UPnA2tQ',
#   'https://play-lh.googleusercontent.com/Wel0rwJIzJY34kOvbz6T_Qiga4RenyXtw6GJ1zid9tBEFicrfGigpsymTxDNOZD2Yvgc',
#   'https://play-lh.googleusercontent.com/QZ5_cPum0SSkYHYQSYizchDqJChCUClRatZTskj51tREDjvwdPn_yFJxIsnFoIaxzw',
#   'https://play-lh.googleusercontent.com/RZ28jBYGE_bXrNLLCzq1agjPWbDj0YbhCGpJghS6c7SPuzSfGOL4QcCe2H2-blyydNs',
#   'https://play-lh.googleusercontent.com/0iP7elefWi85k5FgFYZBYE6L50vj5GuGCOck31BGyh0aRdD4raVBq8KpJrtJ8fF6xh8',
#   'https://play-lh.googleusercontent.com/2l37YHyKQXymqBDYkVAIXgnG9D6TrvVMZa5MFQxjw5IF4oj1Q6jRSzqKq6qM5cC48UI',
#   'https://play-lh.googleusercontent.com/hyNHj70hB1Ub6kM_1qwi74_184Rh4bvMvbKQz9TrFmkuxcqI62BWQZKoeqHWipUAXA4'],
#  'video': None,
#  'videoImage': None,
#  'contentRating': 'Rating 3+',
#  'contentRatingDescription': None,
#  'adSupported': False,
#  'containsAds': False,
#  'released': '9 Agu 2016',
#  'lastUpdatedOn': '25 Mar 2025',
#  'updated': 1742919171,
#  'version': '3.130.0',
#  'comments': [],
#  'appId': 'ovo.id',
#  'url': 'https://play.google.com/store/apps/details?id=ovo.id&hl=id&gl=id'}

# %%
app_id = "ovo.id"

# Mengambil semua review
reviews = reviews_all(
    app_id,
    sleep_milliseconds=0,  # Tidak ada delay
    lang='id',  # Bahasa Indonesia
    country='id',  # Negara Indonesia
    sort=Sort.NEWEST,  # Urutkan berdasarkan terbaru
    filter_score_with=None  # Ambil semua rating
)

# Menyimpan ke dalam file CSV
csv_filename = "reviews_ovo.csv"

# Menulis ke file CSV
with open(csv_filename, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["Nama", "Rating", "Komentar", "Tanggal"])  # Header CSV

    for review in reviews:
        writer.writerow([review['userName'], review['score'], review['content'], review['at']])

print(f"✅ Data telah disimpan di {csv_filename}")
# Out:
# ✅ Data telah disimpan di reviews_ovo.csv

# %% [raw]
# df= pd.read_csv("reviews_ovo.csv")

# %%
df
