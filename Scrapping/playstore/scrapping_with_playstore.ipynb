# %%
from google_play_scraper import app, Sort, reviews_all
import pandas as pd
import csv

result = app(
    'com.bsm.activity2',
    lang='id',
    country='id'
)

# %%
result
# Out:
# {'title': 'BSI Mobile',
#  'description': 'BSI Mobile adalah salah satu saluran distribusi yang dimiliki oleh Bank Syariah Indonesia untuk mengakses rekening yang dimiliki nasabah dengan menggunakan teknologi 3G/4G/5G dan WIFI melalui smartphone.\r\n\r\nFitur:\r\n•\tInfo rekening (informasi saldo, mutasi, dan informasi portofolio)\r\n•\tTransfer (pindah buku, online, SKN, QRIS)\r\n•\tPembayaran (PLN, telepon/HP, akademik, institusi, tiket, asuransi, zakat/infaq, BPJS, MPN, PDAM, Internet/TV Kabel, dan E-commerce)\r\n•\tPembelian (voucher HP, PLN prabayar, E-money, Paket Data, Top Up EWallet, Aqiqah, Streaming Video & Musik, Kartu Debit OTP)\r\n•\tBuka rekening online\r\n•\tE-mas\r\n•\tTarik Tunai Tanpa Kartu\r\n•\tBSI Keyboard\r\n•\tTransaksi Terjadwal\r\n•\tAkses Menu Favorit\r\n•\tUpdate lokasi ATM dan Cabang\r\n•\tPenyimpan data transaksi favorit\r\n•\tShare aktivitas ke sosial media\r\n•\tJadwal shalat dan kalimat inspiratif\r\n•\tAkses sosial media Bank Syariah Indonesia\r\n•\tAkses langsung Bank Syariah Indonesia Call 14040\r\n•\tInformasi produk dan promo Bank Syariah Indonesia\r\n•\tNotifikasi detil transaksi ke email yang didaftarkan\r\n•\tBukti transaksi otomatis tersimpan di kotak masuk\r\n•\tPenambahan biller pembayaran dan pembelian\r\n•\tMenu Rate Mata Uang Asing\r\n•\tPortfolio Nasabah\r\n•\tPermintaan ulang kode aktivasi\r\n•\tDigital Wakaf\r\n\r\nRegistrasi:\r\n1.\tProses Pendaftaran/Registrasi \r\na.\tNasabah bisa melakukan registrasi BSI Mobile secara mandiri menggunakan verifikasi Face Recognition ataupun melalui Kantor Cabang, ATM BSI, dan Bank Syariah Indonesia Call 14040.\r\nb.\tSetelah registrasi berhasil, nasabah akan menerima SMS yang berisi kode aktivasi.\r\n\r\n2.\tProses Download \r\nUntuk ponsel dengan Android, IOS\r\nGoogle Play Store, App Store dengan keyword ‘BSI Mobile’.\r\nPastikan aplikasi BSI Mobile offered by / publisher / by PT Bank Syariah Indonesia, Tbk.\r\n\r\n3.\tProses Aktivasi\r\nNasabah meng-input nomor ponsel dan kode aktivasi yang didapat dari cabang pada saat pendaftaran/registrasi.\r\n\r\nInformasi lebih lanjut, kunjungi Bank Syariah Indonesia terdekat atau hubungi:\r\nBank Syariah Indonesia Call 14040. \r\nwww.bankbsi.co.id',
#  'descriptionHTML': 'BSI Mobile adalah salah satu saluran distribusi yang dimiliki oleh Bank Syariah Indonesia untuk mengakses rekening yang dimiliki nasabah dengan menggunakan teknologi 3G/4G/5G dan WIFI melalui smartphone.<br><br>Fitur:<br>•\tInfo rekening (informasi saldo, mutasi, dan informasi portofolio)<br>•\tTransfer (pindah buku, online, SKN, QRIS)<br>•\tPembayaran (PLN, telepon/HP, akademik, institusi, tiket, asuransi, zakat/infaq, BPJS, MPN, PDAM, Internet/TV Kabel, dan E-commerce)<br>•\tPembelian (voucher HP, PLN prabayar, E-money, Paket Data, Top Up EWallet, Aqiqah, Streaming Video &amp; Musik, Kartu Debit OTP)<br>•\tBuka rekening online<br>•\tE-mas<br>•\tTarik Tunai Tanpa Kartu<br>•\tBSI Keyboard<br>•\tTransaksi Terjadwal<br>•\tAkses Menu Favorit<br>•\tUpdate lokasi ATM dan Cabang<br>•\tPenyimpan data transaksi favorit<br>•\tShare aktivitas ke sosial media<br>•\tJadwal shalat dan kalimat inspiratif<br>•\tAkses sosial media Bank Syariah Indonesia<br>•\tAkses langsung Bank Syariah Indonesia Call 14040<br>•\tInformasi produk dan promo Bank Syariah Indonesia<br>•\tNotifikasi detil transaksi ke email yang didaftarkan<br>•\tBukti transaksi otomatis tersimpan di kotak masuk<br>•\tPenambahan biller pembayaran dan pembelian<br>•\tMenu Rate Mata Uang Asing<br>•\tPortfolio Nasabah<br>•\tPermintaan ulang kode aktivasi<br>•\tDigital Wakaf<br><br>Registrasi:<br>1.\tProses Pendaftaran/Registrasi <br>a.\tNasabah bisa melakukan registrasi BSI Mobile secara mandiri menggunakan verifikasi Face Recognition ataupun melalui Kantor Cabang, ATM BSI, dan Bank Syariah Indonesia Call 14040.<br>b.\tSetelah registrasi berhasil, nasabah akan menerima SMS yang berisi kode aktivasi.<br><br>2.\tProses Download <br>Untuk ponsel dengan Android, IOS<br>Google Play Store, App Store dengan keyword ‘BSI Mobile’.<br>Pastikan aplikasi BSI Mobile offered by / publisher / by PT Bank Syariah Indonesia, Tbk.<br><br>3.\tProses Aktivasi<br>Nasabah meng-input nomor ponsel dan kode aktivasi yang didapat dari cabang pada saat pendaftaran/registrasi.<br><br>Informasi lebih lanjut, kunjungi Bank Syariah Indonesia terdekat atau hubungi:<br>Bank Syariah Indonesia Call 14040. <br>www.bankbsi.co.id',
#  'summary': 'Aplikasi BSI untuk akses rekening nasabah dengan 3G/4G/WIFI melalui smartphone',
#  'installs': '10.000.000+',
#  'minInstalls': 10000000,
#  'realInstalls': 13583560,
#  'score': 3.8070664,
#  'ratings': 218989,
#  'reviews': 143479,
#  'histogram': [48037, 10453, 11683, 14352, 134458],
#  'price': 0,
#  'free': True,
#  'currency': 'IDR',
#  'sale': False,
#  'saleTime': None,
#  'originalPrice': None,
#  'saleText': None,
#  'offersIAP': False,
#  'inAppProductPrice': None,
#  'developer': 'PT Bank Syariah Indonesia, Tbk.',
#  'developerId': 'PT+Bank+Syariah+Indonesia,+Tbk.',
#  'developerEmail': 'developer@bankbsi.co.id',
#  'developerWebsite': 'https://www.bankbsi.co.id',
#  'developerAddress': None,
#  'privacyPolicy': 'https://drive.google.com/file/d/1F9yc85gJuTR9ySW_BiiSeLgzWbk1fKM8/view',
#  'genre': 'Keuangan',
#  'genreId': 'FINANCE',
#  'categories': [{'name': 'Keuangan', 'id': 'FINANCE'}],
#  'icon': 'https://play-lh.googleusercontent.com/37LouKJTsdX7DS28yN9LymTRIMmct9OATRPJrravKoSYKOCd6S6G3obfX_HQPm0pr54',
#  'headerImage': 'https://play-lh.googleusercontent.com/LZhxk_ScTl0U9MoMzkPvKQIRZBSoRTtLgPAq2JMZPAAG3efy9ujWVvx5UYsEg_zWpaKU',
#  'screenshots': ['https://play-lh.googleusercontent.com/jY62YXlls0t29O0zPwxPYbES1rT7sg9LnDFBWoiiDqp00rSxgSFqRjZQ_YQMkoox2w',
#   'https://play-lh.googleusercontent.com/42sDJDil7u91dfOxmToKsxOw9AMCm0kcyMVQaoUZJPIOHSwTmXaSRg6w3iqRTnUfYOo',
#   'https://play-lh.googleusercontent.com/NEg9sjdax6YT10PKfrcEclg_vz-cMSsD7y0qbCRJUi3usdz0xmt2TL25TnatrkKB2xIQ',
#   'https://play-lh.googleusercontent.com/yOi_sibOtuzYcq9kR-S46bYblS60mJui5X0mjxVmChs8G0rv-fn9W7Okogea836iWoj9',
#   'https://play-lh.googleusercontent.com/PNt7mh5ulXCx-R6UjHFY1c5DacE8doNXRnLgpVmVveVt_9H1gG2ix1tKkwn4MZTKIoyl',
#   'https://play-lh.googleusercontent.com/dxPQE4tMPOu5S-_0OBT_Vj8AjUA9JqpZ7IFqs9MoMqlUSzMNEe5gliwqfeExoCA9Qw',
#   'https://play-lh.googleusercontent.com/39uOeZ9ZDflTPvSJjb7K8Lt_GvWHJZuHV-9MHKH0hF80B4UEVYmogN0mRGC5FVJ9Ew',
#   'https://play-lh.googleusercontent.com/neh-inUbFUFU4Ar1lgVMm7g4IrpI__GjxSCo0bkPeUf8LNmxaVp6nhuzWD9TAELfX2K3'],
#  'video': None,
#  'videoImage': None,
#  'contentRating': 'Rating 3+',
#  'contentRatingDescription': None,
#  'adSupported': False,
#  'containsAds': False,
#  'released': '12 Apr 2018',
#  'lastUpdatedOn': '14 Sep 2025',
#  'updated': 1757862655,
#  'version': '6.26.2',
#  'comments': [],
#  'appId': 'com.bsm.activity2',
#  'url': 'https://play.google.com/store/apps/details?id=com.bsm.activity2&hl=id&gl=id'}

# %%
app_id = "com.bsm.activity2"

# Mengambil semua review
reviews = reviews_all(
    app_id,
    sleep_milliseconds=0,  # Tidak ada delay
    lang='id',  # Bahasa Indonesia
    country='id',  # Negara Indonesia
    sort=Sort.NEWEST,  # Urutkan berdasarkan terbaru
    filter_score_with=None  # Ambil semua rating
)

# Menyimpan ke dalam file CSV
csv_filename = "reviews_ovo.csv"

# Menulis ke file CSV
with open(csv_filename, mode="w", newline="", encoding="utf-8") as file:
    writer = csv.writer(file)
    writer.writerow(["Nama", "Rating", "Komentar", "Tanggal"])  # Header CSV

    for review in reviews:
        writer.writerow([review['userName'], review['score'], review['content'], review['at']])

print(f"✅ Data telah disimpan di {csv_filename}")
# Out:
# ✅ Data telah disimpan di reviews_ovo.csv

# %%
df= pd.read_csv("reviews_ovo.csv")

# %%
df
# Out:
#                    Nama  Rating  \
# 0       Pengguna Google       1
# 1       Pengguna Google       5
# 2       Pengguna Google       5
# 3       Pengguna Google       2
# 4       Pengguna Google       5
# ...                 ...     ...
# 128654  Pengguna Google       5
# 128655  Pengguna Google       5
# 128656  Pengguna Google       5
# 128657  Pengguna Google       5
# 128658  Pengguna Google       5
#
#                                                  Komentar              Tanggal
# 0       aplikasi bukan nya mempermudah . malah memper ...  2025-10-13 18:30:43
# 1                          Terima kasih atas perhatiannya  2025-10-13 10:28:05
# 2       JANGAN DIGANTI TLG, SAYA NYAMAN PAKE BSI MOBIL...  2025-10-13 09:54:39
# 3       saya mau bayar tiket kapal Ferry, padahal suda...  2025-10-12 21:51:11
# 4              game menyenangkan ,tapi nggk pernah jakpot  2025-10-12 12:52:30
# ...                                                   ...                  ...
# 128654  Terima kasih BSM sngat memudahkan saya dalam b...  2018-04-19 07:21:36
# 128655   Lebih Praktis, transaksi tinggal scan.. Kereeeen  2018-04-19 07:17:29
# 128656             Alhamdulillah.. sukses terus utk BSM..  2018-04-19 06:54:33
# 128657                        Keren. Bisa buka rek online  2018-04-19 06:53:19
# 128658                               mantappp, love it 😊😊  2018-04-19 06:33:44
#
# [128659 rows x 4 columns]
